# %%
import trader.Cerebro as cb
import trader.feed as feed
from pymongo import MongoClient

# %%
data = feed.get_data(symbol = 'BTC/USDT', date= '2024-04-01')
Strategy = cb.Strategy(data)
cerebro = cb.Cerebro(Strategy, InitialPortfolio={"USDT" : 100000})
cerebro.run(symbol='BTC/USDT')
# Out:
# Bought 0.001 for 71268.06 each at index 2
# Bought 0.001 for 71250.0 each at index 3
# Sold 0.001 for 71250.01 each at index 4
# Bought 0.001 for 71250.0 each at index 5
# Bought 0.001 for 71230.52 each at index 6
# Bought 0.001 for 71221.26 each at index 7
# Bought 0.001 for 71211.0 each at index 8
# Bought 0.001 for 71208.96 each at index 9
# Sold 0.001 for 71208.97 each at index 10
# Bought 0.001 for 71208.96 each at index 13
# Bought 0.001 for 71204.14 each at index 14
# Bought 0.001 for 71202.6 each at index 15
# Bought 0.001 for 71202.59 each at index 16
# Sold 0.001 for 71202.6 each at index 17
# Sold 0.001 for 71211.99 each at index 18
# Sold 0.001 for 71213.34 each at index 19
# Sold 0.001 for 71216.08 each at index 20
# Bought 0.001 for 71202.61 each at index 22
# Bought 0.001 for 71192.7 each at index 23
# Sold 0.001 for 71194.0 each at index 24
# Sold 0.001 for 71196.0 each at index 25
# Sold 0.001 for 71199.99 each at index 27
# Sold 0.001 for 71200.0 each at index 28
# ...
